# %% [markdown]
# <a href="https://colab.research.google.com/github/imxogml/modeling_by_chatGPT/blob/main/chatgpt_FMNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chat GPT 이용: Fashion mnist dataset을 사용해서 val loss 최소값인 모델 구현하기
# **prompt**
# - please code classification model from fashionmnist dataset in tensorflow, using Dense and BatchNormalization

# %%
import tensorflow as tf
import numpy as np

# Load FashionMNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Normalize pixel values to be between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# Flatten input images into a vector
x_train = x_train.reshape((-1, 28 * 28))
x_test = x_test.reshape((-1, 28 * 28))

# Convert labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Define the model architecture
model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, input_shape=(28 * 28,)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Dense(128),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Dense(64),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model with appropriate loss function and optimizer
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=100, batch_size=256)

# Evaluate the model on test data
loss, accuracy = model.evaluate(x_test, y_test)
print("Test accuracy:", accuracy)
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/100
# 235/235 [==============================] - 9s 5ms/step - loss: 0.4835 - accuracy: 0.8351
# Epoch 2/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3202 - accuracy: 0.8836
# Epoch 3/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2822 - accuracy: 0.8975
# Epoch 4/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2524 - accuracy: 0.9069
# Epoch 5/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2319 - accuracy: 0.9139
# Epoch 6/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2128 - accuracy: 0.9219
# Epoch 7/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1970 - accuracy: 0.9266
# Epoch 8/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1824 - accuracy: 0.9319
# Epoch 9/100
# ...
